# %%
import import_ipynb
from model_development import *

# %%
model = PneumoniaDetector().to(device)
state_dict_name = 'PneumoniaDetector_2024-04-10_01-19-39.pth'

model.load_state_dict(torch.load(os.path.join(model_save_path, state_dict_name)))
# Out:
# <All keys matched successfully>

# %%
random_pred(dataset, model, classes=dataset.classes)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# Raw Logits:                   tensor([-10.5417,   7.4113,  -6.4425], device='cuda:0')
# Prediction Probabilities:     tensor([1.5963e-08, 1.0000e+00, 9.6243e-07], device='cuda:0')
# Prediction Labels:            1
#
# Prediction: PNEUMONIA_BACTERIAL
# Target: PNEUMONIA_BACTERIAL
